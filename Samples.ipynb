# %%
import pandas

# %%
pandas.read_csv('src-data/DRIVERS.csv', index_col=0).sample(5)
# Out:
#           Driver  GroundSpeed  WaterSpeed  AirSpeed  AntiGravitySpeed  \
# 26          Iggy         3.75        4.00      4.25              3.50
# 7   Koopa Troopa         2.75        3.00      3.25              2.50
# 13          Toad         3.00        3.25      3.50              2.75
# 21         Yoshi         3.50        3.75      4.00              3.25
# 15         Larry         3.00        3.25      3.50              2.75
#
#     Acceleration  Weight  GroundHandling  WaterHandling  AirHandling  \
# 26          3.50    3.50            3.75           3.25         3.75
# 7           4.00    2.50            4.50           4.00         4.50
# 13          4.00    2.75            4.25           3.75         4.25
# 21          3.75    3.00            3.75           3.25         3.75
# 15          4.00    2.75            4.25           3.75         4.25
#
#     AntiGravityHandling  Traction  MiniTurbo
# 26                 3.75      3.25       3.25
# ...

# %%
pandas.read_csv('src-data/VEHICLES.csv', index_col=0).sample(5)
# Out:
#               Vehicle  GroundSpeed  WaterSpeed  AirSpeed  AntiGravitySpeed  \
# 28            Varmint        -0.50        0.00      -0.5             -0.50
# 25        Sport Bike+         0.25        0.00       0.0              0.00
# 38        Splat Buggy         0.25       -0.25       0.0              0.25
# 15  W 25 Silver Arrow        -0.25       -0.25       0.0              0.25
# 22        Koopa Clown        -0.25        0.25       0.0              0.00
#
#     Acceleration  Weight  GroundHandling  WaterHandling  AirHandling  \
# 28          0.50   -0.25            0.50           0.50        -0.25
# 25         -0.50   -0.25            0.00           0.25         0.00
# 38         -0.25   -0.50           -0.25           0.25        -0.50
# 15          0.25   -0.25            0.25           0.25         0.00
# 22         -0.50    0.25            0.25           0.50         0.00
#
#     AntiGravityHandling  Traction  MiniTurbo
# 28                 0.25      0.25       0.50
# ...

# %%
pandas.read_csv('src-data/TIRES.csv', index_col=0).sample(5)
# Out:
#             Tire  GroundSpeed  WaterSpeed  AirSpeed  AntiGravitySpeed  \
# 39       Cushion        -0.25        -0.5      0.25             -0.25
# 74    GLA Wheels         0.00         0.0      0.00              0.00
# 30        Sponge        -0.25        -0.5      0.25             -0.25
# 18         Metal         0.50         0.0     -0.25             -0.25
# 53  Azure Roller        -0.50         0.0      0.00             -0.50
#
#     Acceleration  Weight  GroundHandling  WaterHandling  AirHandling  \
# 39           0.0   -0.25           -0.25          -0.50         0.00
# 74           0.0    0.00            0.00           0.00         0.00
# 30           0.0   -0.25           -0.25          -0.50         0.00
# 18          -1.0    0.50           -0.25          -0.25        -0.75
# 53           0.5   -0.50            0.25           0.25         0.25
#
#     AntiGravityHandling  Traction  MiniTurbo
# 39                -0.25      0.25       0.25
# ...

# %%
pandas.read_csv('src-data/GLIDERS.csv', index_col=0).sample(5)
# Out:
#           Glider  GroundSpeed  WaterSpeed  AirSpeed  AntiGravitySpeed  \
# 17     Parachute        -0.25        0.00     -0.25              0.25
# 41   Gold Glider         0.00       -0.25      0.00              0.25
# 33  Plane Glider         0.00       -0.25      0.00              0.25
# 49  Paper Glider        -0.25        0.00     -0.25              0.25
# 29   Bowser Kite        -0.25       -0.25     -0.25              0.25
#
#     Acceleration  Weight  GroundHandling  WaterHandling  AirHandling  \
# 17          0.25   -0.25             0.0           0.00         0.25
# 41          0.00    0.25             0.0           0.25         0.00
# 33          0.00    0.25             0.0           0.25         0.00
# 49          0.25   -0.25             0.0           0.00         0.25
# 29          0.25    0.00             0.0           0.25         0.25
#
#     AntiGravityHandling  Traction  MiniTurbo
# 17                 0.00      0.00       0.25
# ...

# %%
pandas.read_csv('output/COMBOS.csv', index_col=0).sample(5)
# Out:
#                Driver          Vehicle            Tire        Glider  \
# 371655       Rosalina           Comet+          Roller   Gold Glider
# 90522    Koopa Troopa      Flame Rider      GLA Wheels   Hylian Kite
# 265385  Tanooki Mario      Koopa Clown    Crimson Slim  Cloud Glider
# 347147    Metal Mario         Streetle  Retro Off-Road   Waddle Wing
# 4971       Baby Peach  300 SL Roadster  Triforce Tyres  Cloud Glider
#
#         GroundSpeed  WaterSpeed  AirSpeed  AntiGravitySpeed  Acceleration  \
# 371655         3.25        3.75      4.75              3.50          4.00
# 90522          2.50        2.75      3.25              2.75          4.25
# 265385         3.25        3.75      3.50              4.00          3.00
# 347147         4.00        5.25      4.00              3.25          3.50
# 4971           2.25        2.75      2.00              2.25          4.00
#
#         Weight  GroundHandling  WaterHandling  AirHandling  \
# ...

# %%
pandas.read_csv('output/COMBOS_EXTRA.csv', index_col=0).sample(5)
# Out:
#               Driver        Vehicle         Tire        Glider  GroundSpeed  \
# 445363         Wario  Standard Quad  Gold Wheels  Plane Glider         5.75
# 309066          Iggy        Bounder        Metal    Wario Wing         4.50
# 223285  Villager (F)     Inkstriker       Wooden  Paper Glider         3.25
# 42165          Lemmy  Standard Bike       Sponge   Gold Glider         1.75
# 329280        Ludwig  Standard Kart       Normal  Super Glider         3.75
#
#         WaterSpeed  AirSpeed  AntiGravitySpeed  Acceleration  Weight  \
# 445363        4.50      4.50              4.50           1.0    5.50
# 309066        3.50      4.00              3.50           2.0    4.25
# 223285        3.25      3.50              4.25           3.5    2.75
# 42165         1.50      3.00              2.25           4.5    1.75
# 329280        4.00      4.25              3.50           3.5    3.50
#
#               ...         AverageSpeed  WeightedSpeed  AverageHandling  \
# ...

# %%
pandas.read_csv('output/MINIFIED.csv', index_col=0).sample(5)
# Out:
#        index         Driver        Vehicle            Tire        Glider  \
# 1327   78868      Dry Bones        Varmint           Metal      Parafoil
# 6198  192092      Cat Peach      Gold Kart        Off-Road   Hylian Kite
# 7592  194572      Cat Peach         P-Wing     Gold Wheels  Super Glider
# 1929   33207  Baby Rosalina  Master Cycle+  Triforce Tyres  Paper Glider
# 4770  300589          Luigi    Koopa Clown          Sponge  Plane Glider
#
#       GroundSpeed  WaterSpeed  AirSpeed  AntiGravitySpeed  Acceleration  \
# 1327         2.25         2.5      2.00              1.75          4.00
# 6198         3.75         3.5      3.25              3.00          3.25
# 7592         4.25         3.0      3.25              3.00          2.25
# 1929         2.50         2.5      2.00              2.25          3.75
# 4770         3.25         3.5      4.50              3.50          3.00
#
#             ...         AverageSpeed  WeightedSpeed  AverageHandling  \
# ...

# %%
winners = pandas.read_csv('output/WINNERS.csv', index_col=0)
winners
# Out:
#                    Stat         Driver        Vehicle          Tire  \
# 0           GroundSpeed         Bowser  Standard Quad         Metal
# 1            WaterSpeed         Bowser       Landship      Off-Road
# 2              AirSpeed     Dry Bowser    Cat Cruiser        Sponge
# 3      AntiGravitySpeed         Bowser   Sports Coupé   Cyber Slick
# 4          Acceleration  Baby Rosalina       Buggybud  Azure Roller
# 5                Weight         Bowser   Steel Driver         Metal
# 6        GroundHandling     Baby Daisy       Buggybud  Azure Roller
# 7         WaterHandling     Baby Daisy       Landship        Wooden
# 8           AirHandling     Baby Daisy       Buggybud  Azure Roller
# 9   AntiGravityHandling     Baby Daisy    Blue Falcon  Azure Roller
# 10             Traction   Koopa Troopa    Koopa Clown       Monster
# 11            MiniTurbo     Baby Daisy       Buggybud  Azure Roller
# 12                Total    Metal Mario    Koopa Clown        Roller
# ...

# %%
print("| Stat | Driver | Vehicle | Tire | Glider | Value |")
print("| --- | --- | --- | --- | --- | --- |")

for i in winners.iterrows():
    
    row = i[1]
    
    print("| {} | {} | {} | {} | {} | {} |".format(
        row.Stat,
        row.Driver,
        row.Vehicle,
        row.Tire,
        row.Glider,
        float(row.Value)
    ))
# Out:
# | Stat | Driver | Vehicle | Tire | Glider | Value |
# | --- | --- | --- | --- | --- | --- |
# | GroundSpeed | Bowser | Standard Quad | Metal | Waddle Wing | 5.75 |
# | WaterSpeed | Bowser | Landship | Off-Road | Cloud Glider | 5.75 |
# | AirSpeed | Dry Bowser | Cat Cruiser | Sponge | Wario Wing | 5.75 |
# | AntiGravitySpeed | Bowser | Sports Coupé | Cyber Slick | Flower Glider | 5.75 |
# | Acceleration | Baby Rosalina | Buggybud | Azure Roller | Parafoil | 5.75 |
# | Weight | Bowser | Steel Driver | Metal | Gold Glider | 5.75 |
# | GroundHandling | Baby Daisy | Buggybud | Azure Roller | Bowser Kite | 5.75 |
# | WaterHandling | Baby Daisy | Landship | Wooden | Gold Glider | 5.75 |
# | AirHandling | Baby Daisy | Buggybud | Azure Roller | Bowser Kite | 5.75 |
# | AntiGravityHandling | Baby Daisy | Blue Falcon | Azure Roller | Flower Glider | 5.75 |
# | Traction | Koopa Troopa | Koopa Clown | Monster | Flower Glider | 5.75 |
# ...
